# %%
import pandas as pd
df = pd.read_excel('NFL Combine Data.xlsx')

# %%
df.dtypes
# Out:
# Year                 int64
# Name                object
# College             object
# POS                 object
# Height (in)        float64
# Weight (lbs)         int64
# Hand Size (in)     float64
# Arm Length (in)    float64
# Wonderlic          float64
# 40 Yard            float64
# Bench Press        float64
# Vert Leap (in)     float64
# Broad Jump (in)    float64
# Shuttle            float64
# 3Cone              float64
# 60Yd Shuttle       float64
# dtype: object

# %%
df.shape
# Out:
# (10228, 16)

# %%
df.columns
# Out:
# Index(['Year', 'Name', 'College', 'POS', 'Height (in)', 'Weight (lbs)',
#        'Hand Size (in)', 'Arm Length (in)', 'Wonderlic', '40 Yard',
#        'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone',
#        '60Yd Shuttle'],
#       dtype='object')

# %%
df.head()
# Out:
#    Year             Name          College POS  Height (in)  Weight (lbs)  \
# 0  2018       Josh Adams       Notre Dame  RB         74.0           213
# 1  2018      Ola Adeniyi           Toledo  DE         74.0           248
# 2  2018     Jordan Akins  Central Florida  TE         75.0           249
# 3  2018  Jaire Alexander       Louisville  CB         71.0           192
# 4  2018     Austin Allen         Arkansas  QB         72.0           210
#
#    Hand Size (in)  Arm Length (in)  Wonderlic  40 Yard  Bench Press  \
# 0            9.25            33.75        NaN      NaN         18.0
# 1            9.63            31.75        NaN     4.83         26.0
# 2            9.50            32.50        NaN      NaN          NaN
# 3             NaN              NaN        NaN     4.38         14.0
# 4            9.63            30.63        NaN     4.81          NaN
#
#    Vert Leap (in)  Broad Jump (in)  Shuttle  3Cone  60Yd Shuttle
# ...

# %%
df.tail()
# Out:
#        Year             Name     College  POS  Height (in)  Weight (lbs)  \
# 10223  1987      Rod Woodson      Purdue   CB         72.0           202
# 10224  1987  John Wooldridge  Ohio State   RB         68.4           193
# 10225  1987      David Wyman    Stanford  ILB         74.0           235
# 10226  1987       Theo Young    Arkansas   TE         74.0           231
# 10227  1987   Jeff Zimmerman     Florida   OG         75.4           341
#
#        Hand Size (in)  Arm Length (in)  Wonderlic  40 Yard  Bench Press  \
# 10223            10.5            31.00        NaN     4.33         10.0
# 10224             NaN              NaN        NaN      NaN          NaN
# 10225             9.5            31.25        NaN     4.79         23.0
# 10226             9.0            34.00        NaN     4.89          9.0
# 10227             9.0            33.50        NaN     5.36         22.0
#
#        Vert Leap (in)  Broad Jump (in)  Shuttle  3Cone  60Yd Shuttle
# ...

# %%
df.describe()
# Out:
#                Year   Height (in)  Weight (lbs)  Hand Size (in)  \
# count  10228.000000  10228.000000  10228.000000     8621.000000
# mean    2002.438600     73.741555    240.183125        9.531669
# std       21.930191      2.638082     44.937472        0.627339
# min        5.000000     64.900000    142.000000        7.130000
# 25%     1994.000000     71.900000    203.000000        9.130000
# 50%     2002.000000     74.000000    232.000000        9.500000
# 75%     2012.000000     75.750000    275.000000       10.000000
# max     2018.000000     82.400000    387.000000       11.880000
#
#        Arm Length (in)   Wonderlic      40 Yard  Bench Press  Vert Leap (in)  \
# count      8303.000000  431.000000  9292.000000  6977.000000     8258.000000
# mean         32.223198   24.044084     4.828435    19.822703       32.022463
# std           1.493612    7.614576     0.309596     6.522123        4.202037
# min          25.630000    4.000000     4.210000     1.000000       17.500000
# ...

# %%
df
# Out:
#        Year             Name          College  POS  Height (in)  Weight (lbs)  \
# 0      2018       Josh Adams       Notre Dame   RB         74.0           213
# 1      2018      Ola Adeniyi           Toledo   DE         74.0           248
# 2      2018     Jordan Akins  Central Florida   TE         75.0           249
# 3      2018  Jaire Alexander       Louisville   CB         71.0           192
# 4      2018     Austin Allen         Arkansas   QB         72.0           210
# ...     ...              ...              ...  ...          ...           ...
# 10223  1987      Rod Woodson           Purdue   CB         72.0           202
# 10224  1987  John Wooldridge       Ohio State   RB         68.4           193
# 10225  1987      David Wyman         Stanford  ILB         74.0           235
# 10226  1987       Theo Young         Arkansas   TE         74.0           231
# 10227  1987   Jeff Zimmerman          Florida   OG         75.4           341
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['3Cone']
# Out:
# 0         NaN
# 1        7.21
# 2         NaN
# 3        6.71
# 4        7.18
#          ...
# 10223     NaN
# 10224     NaN
# 10225     NaN
# 10226     NaN
# 10227     NaN
# Name: 3Cone, Length: 10228, dtype: float64

# %%
new_df = df[["Year","Name","POS", "Shuttle"]]
new_df
# Out:
#        Year             Name  POS  Shuttle
# 0      2018       Josh Adams   RB      NaN
# 1      2018      Ola Adeniyi   DE     4.28
# 2      2018     Jordan Akins   TE      NaN
# 3      2018  Jaire Alexander   CB     3.98
# 4      2018     Austin Allen   QB     4.48
# ...     ...              ...  ...      ...
# 10223  1987      Rod Woodson   CB     3.98
# 10224  1987  John Wooldridge   RB      NaN
# 10225  1987      David Wyman  ILB     4.30
# 10226  1987       Theo Young   TE     4.20
# 10227  1987   Jeff Zimmerman   OG     4.83
#
# [10228 rows x 4 columns]

# %%
column_names = df.columns
column_names
# Out:
# Index(['Year', 'Name', 'College', 'POS', 'Height (in)', 'Weight (lbs)',
#        'Hand Size (in)', 'Arm Length (in)', 'Wonderlic', '40 Yard',
#        'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone',
#        '60Yd Shuttle'],
#       dtype='object')

# %%
df.get('60Yd Shuttle')
# Out:
# 0          NaN
# 1        12.79
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 10223    10.92
# 10224      NaN
# 10225    11.78
# 10226    11.71
# 10227      NaN
# Name: 60Yd Shuttle, Length: 10228, dtype: float64

# %%
#Below, I grouped each position into its own dataframe: only includes players w/ valid Shuttle, 3Cone, Bench Press, 40, and Year between 1985 and 2015 (so it matches w/ draft dataset I'll look into later)

# %%
rbs =  df[(df["POS"] == "RB")&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 1985)&(df['Year'] < 2016)&(df['40\xa0Yard'] > 2)]
rbs
# Out:
#       Year            Name              College POS  Height (in)  \
# 916   2015  Ameer Abdullah             Nebraska  RB        68.75
# 919   2015       Jay Ajayi          Boise State  RB        71.75
# 924   2015  Javorius Allen  Southern California  RB        72.50
# 986   2015   Malcolm Brown                Texas  RB        71.38
# 1049  2015   John Crockett   North Dakota State  RB        71.75
# ...    ...             ...                  ...  ..          ...
# 6820  1997      Alex Smith              Indiana  RB        71.40
# 6844  1997  David Thompson       Oklahoma State  RB        68.30
# 6853  1997    Corey Walker        Arizona State  RB        69.50
# 6867  1997     Cj Williams         Georgia Tech  RB        72.10
# 6871  1997      Abu Wilson           Utah State  RB        72.40
#
#       Weight (lbs)  Hand Size (in)  Arm Length (in)  Wonderlic  40 Yard  \
# 916            205            8.63            30.00        NaN     4.60
# ...

# %%
tes =  df[(df["POS"] == "TE")&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 1985)&(df['Year'] < 2016)&(df['40\xa0Yard'] > 2)]
tes
# Out:
#       Year              Name          College POS  Height (in)  Weight (lbs)  \
# 951   2015        Blake Bell         Oklahoma  TE        78.25           252
# 976   2015        Nick Boyle         Delaware  TE        76.50           268
# 1015  2015  Gerald Christian       Louisville  TE        75.00           244
# 1250  2015       Jesse James       Penn State  TE        79.00           261
# 1407  2015      Nick O'Leary    Florida State  TE        75.25           252
# ...    ...               ...              ...  ..          ...           ...
# 6722  1997  Ronald Leshinski             Army  TE        74.30           246
# 6724  1997        Chad Lewis    Brigham Young  TE        77.40           248
# 6736  1997       Kris Mangum      Mississippi  TE        76.50           249
# 6806  1997      O J Santiago  Kent State (OH)  TE        78.90           267
# 6865  1997       Josh Wilcox           Oregon  TE        74.60           256
#
# ...

# %%
wrs =  df[(df["POS"] == "WR")&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 1985)&(df['Year'] < 2016)&(df['40\xa0Yard'] > 2)]
wrs
# Out:
#       Year              Name                   College POS  Height (in)  \
# 922   2015      Mario Alford             West Virginia  WR        68.50
# 952   2015        Kenny Bell                  Nebraska  WR        73.13
# 982   2015      Da'Ron Brown         Northern Illinois  WR        72.13
# 1023  2015       Kaelin Clay                      Utah  WR        69.63
# 1028  2015     Sammie Coates                    Auburn  WR        73.38
# ...    ...               ...                       ...  ..          ...
# 4137  2006  Brandon Marshall           Central Florida  WR        76.50
# 4247  2006      Todd Watkins             Brigham Young  WR        74.38
# 4259  2006  Brandon Williams                 Wisconsin  WR        69.38
# 4471  2005        Chad Owens                    Hawaii  WR        67.38
# 4488  2005    Jamaica Rector  Northwest Missouri State  WR        69.75
#
#       Weight (lbs)  Hand Size (in)  Arm Length (in)  Wonderlic  40 Yard  \
# ...

# %%
ots = df[(df["POS"] == "OT")&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 1985)&(df['Year'] < 2016)&(df['40\xa0Yard'] > 2)]
ots
# Out:
#       Year               Name               College POS  Height (in)  \
# 988   2015        Trent Brown               Florida  OT        80.50
# 1025  2015     T.J. Clemmings            Pittsburgh  OT        76.75
# 1030  2015     Takoby Cofield                  Duke  OT        76.25
# 1035  2015      La`el Collins       Louisiana State  OT        76.50
# 1048  2015          Rob Crisp  North Carolina State  OT        78.63
# ...    ...                ...                   ...  ..          ...
# 6797  1997         Juan Roque         Arizona State  OT        80.00
# 6799  1997  Raleigh Roundtree  South Carolina State  OT        76.60
# 6805  1997    Scott Sanderson      Washington State  OT        78.10
# 6833  1997       Todd Stewart            California  OT        77.10
# 6847  1997          Adam Treu              Nebraska  OT        77.40
#
#       Weight (lbs)  Hand Size (in)  Arm Length (in)  Wonderlic  40 Yard  \
# ...

# %%
ogs = df[(df["POS"] == "OG")&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 1985)&(df['Year'] < 2016)&(df['40\xa0Yard'] > 2)]
ogs
# Out:
#       Year             Name                      College POS  Height (in)  \
# 968   2015          Al Bond                      Memphis  OG        75.75
# 1090  2015    Jamil Douglas                Arizona State  OG        76.00
# 1152  2015   Mark Glowinski                West Virginia  OG        76.38
# 1202  2015  Jarvis Harrison                    Texas A&M  OG        76.13
# 1339  2015       Ali Marpet  Hobart & William Smith (NY)  OG        75.88
# ...    ...              ...                          ...  ..          ...
# 6759  1997      Larry Moore                Brigham Young  OG        74.60
# 6765  1997     Brian Newnam                   Tulsa (OK)  OG        75.40
# 6807  1997         Bob Sapp                   Washington  OG        76.40
# 6811  1997    Steve Scifres                      Wyoming  OG        75.90
# 6840  1997    Daryl Terrell         Southern Mississippi  OG        76.50
#
#       Weight (lbs)  Hand Size (in)  Arm Length (in)  Wonderlic  40 Yard  \
# ...

# %%
cs = df[(df["POS"] == "C")&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 1985)&(df['Year'] < 2016)&(df['40\xa0Yard'] > 2)]
cs
# Out:
#       Year                Name         College POS  Height (in)  Weight (lbs)  \
# 1081  2015      Reese Dismukes          Auburn   C        74.75           296
# 1112  2015      Cameron Erving   Florida State   C        77.50           313
# 1141  2015         Andy Gallik  Boston College   C        74.38           306
# 1770  2014  Jonotthan Harrison         Florida   C        75.50           304
# 1786  2014          Gabe Ikard        Oklahoma   C        75.63           304
# ...    ...                 ...             ...  ..          ...           ...
# 6417  1998          Kevin Long   Florida State   C        77.30           296
# 6449  1998     Jeremy Newberry      California   C        76.90           314
# 6494  1998       Jeff Saturday  North Carolina   C        74.40           292
# 6519  1998   Nathan Strikwerda    Northwestern   C        76.10           296
# 6768  1997       Daniel Palmer       Air Force   C        76.30           290
#
# ...

# %%
df.columns[df.any()].tolist()
# Out:
# ['Year',
#  'Name',
#  'College',
#  'POS',
#  'Height\xa0(in)',
#  'Weight\xa0(lbs)',
#  'Hand Size\xa0(in)',
#  'Arm Length\xa0(in)',
#  'Wonderlic',
#  '40\xa0Yard',
#  'Bench Press',
#  'Vert Leap\xa0(in)',
#  'Broad Jump\xa0(in)',
#  'Shuttle',
#  '3Cone',
#  '60Yd Shuttle']

# %%
tes.describe()
# Out:
#               Year  Height (in)  Weight (lbs)  Hand Size (in)  \
# count   213.000000   213.000000    213.000000      183.000000
# mean   2005.521127    76.262300    255.403756        9.761803
# std       5.278630     1.341787     11.714625        0.516339
# min    1997.000000    73.380000    226.000000        7.880000
# 25%    2001.000000    75.300000    248.000000        9.500000
# 50%    2006.000000    76.130000    254.000000        9.750000
# 75%    2010.000000    77.130000    261.000000       10.130000
# max    2015.000000    80.000000    336.000000       11.000000
#
#        Arm Length (in)  Wonderlic     40 Yard  Bench Press  Vert Leap (in)  \
# count       184.000000   4.000000  213.000000   213.000000        211.0000
# mean         32.954946  27.000000    4.814883    20.441315         32.7109
# std           1.032216   3.162278    0.153157     4.358096          3.2866
# min          29.750000  23.000000    4.390000     7.000000         24.5000
# ...

# %%
rbs.describe()
# Out:
#               Year  Height (in)  Weight (lbs)  Hand Size (in)  \
# count   274.000000   274.000000    274.000000      235.000000
# mean   2006.127737    70.563029    213.981752        9.282085
# std       5.817282     1.744406     13.569642        0.511489
# min    1997.000000    65.750000    180.000000        7.250000
# 25%    2000.000000    69.400000    205.000000        9.000000
# 50%    2006.000000    70.500000    214.000000        9.250000
# 75%    2011.000000    71.720000    223.000000        9.630000
# max    2015.000000    76.300000    267.000000       10.630000
#
#        Arm Length (in)  Wonderlic     40 Yard  Bench Press  Vert Leap (in)  \
# count       234.000000  12.000000  274.000000   274.000000      270.000000
# mean         30.988376  20.000000    4.572920    19.240876       34.863704
# std           1.126961   5.376717    0.118687     4.483630        2.885114
# min          28.000000  11.000000    4.290000     3.000000       27.000000
# ...

# %%
wrs.describe()
# Out:
#               Year  Height (in)  Weight (lbs)  Hand Size (in)  \
# count   196.000000   196.000000    196.000000      166.000000
# mean   2011.438776    72.755408    203.403061        9.349699
# std       2.650849     2.439770     14.729555        0.484177
# min    2005.000000    65.250000    166.000000        8.250000
# 25%    2010.000000    71.130000    192.000000        9.000000
# 50%    2012.000000    72.815000    204.000000        9.280000
# 75%    2014.000000    74.500000    214.000000        9.630000
# max    2015.000000    78.130000    240.000000       10.630000
#
#        Arm Length (in)  Wonderlic     40 Yard  Bench Press  Vert Leap (in)  \
# count       166.000000  12.000000  196.000000   196.000000      196.000000
# mean         32.088072  19.583333    4.504388    15.153061       35.456633
# std           1.371440   8.732992    0.101674     4.980685        3.271384
# min          27.880000   7.000000    4.210000     4.000000       24.500000
# ...

# %%
ots.describe()
# Out:
#               Year  Height (in)  Weight (lbs)  Hand Size (in)  \
# count   299.000000   299.000000    299.000000      253.000000
# mean   2006.066890    77.565017    314.896321        9.984506
# std       5.549249     1.146217     15.287160        0.532103
# min    1997.000000    74.800000    281.000000        8.880000
# 25%    2001.000000    76.750000    305.000000        9.630000
# 50%    2006.000000    77.500000    313.000000       10.000000
# 75%    2011.000000    78.250000    323.000000       10.250000
# max    2015.000000    80.500000    387.000000       11.750000
#
#        Arm Length (in)  Wonderlic     40 Yard  Bench Press  Vert Leap (in)  \
# count       259.000000  10.000000  299.000000   299.000000      298.000000
# mean         33.836255  22.700000    5.278227    24.046823       28.013423
# std           1.156685   6.566751    0.187380     5.059825        3.008376
# min          30.630000  12.000000    4.710000     9.000000       21.000000
# ...

# %%
ogs.describe()
# Out:
#               Year  Height (in)  Weight (lbs)  Hand Size (in)  \
# count   247.000000   247.000000    247.000000      215.000000
# mean   2005.526316    75.986640    313.659919        9.900047
# std       5.453267     1.129452     12.721123        0.496851
# min    1997.000000    73.000000    282.000000        8.630000
# 25%    2001.000000    75.250000    305.000000        9.500000
# 50%    2005.000000    76.000000    312.000000        9.880000
# 75%    2011.000000    76.775000    320.000000       10.250000
# max    2015.000000    79.250000    367.000000       11.380000
#
#        Arm Length (in)  Wonderlic     40 Yard  Bench Press  Vert Leap (in)  \
# count       218.000000   5.000000  247.000000   247.000000      242.000000
# mean         33.174495  26.600000    5.329919    25.400810       27.494628
# std           1.183228   8.264381    0.188393     5.070767        2.954414
# min          30.500000  14.000000    4.960000    14.000000       20.500000
# ...

# %%
cs.describe()
# Out:
#               Year  Height (in)  Weight (lbs)  Hand Size (in)  \
# count   122.000000   122.000000    122.000000       94.000000
# mean   2005.762295    75.256721    302.532787        9.747872
# std       5.174721     1.061350      9.500052        0.456065
# min    1997.000000    72.400000    263.000000        8.250000
# 25%    2001.000000    74.630000    298.000000        9.500000
# 50%    2006.000000    75.250000    302.000000        9.750000
# 75%    2010.000000    76.000000    308.750000       10.097500
# max    2015.000000    78.000000    336.000000       10.880000
#
#        Arm Length (in)  Wonderlic     40 Yard  Bench Press  Vert Leap (in)  \
# count        94.000000        1.0  122.000000   122.000000      121.000000
# mean         32.412979       31.0    5.261148    26.139344       28.326446
# std           1.041937        NaN    0.163066     5.058853        2.905964
# min          29.500000       31.0    4.860000    14.000000       21.000000
# ...

# %%
plt = cs[["Bench Press"]].plot(
    kind="hist", 
    bins = [10, 15, 20, 25, 30, 35,40,45], 
    rwidth=0.8
)

# %%
plt= cs.plot(x='40\xa0Yard', y = "Shuttle", kind="scatter")

# %%
edges2012 = df[((df["POS"] == "DE") | (df["POS"] == "OLB"))&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 2011)&(df['Year'] < 2013)&(df['40\xa0Yard'] > 2)]
edges2012
# Out:
#       Year                Name               College  POS  Height (in)  \
# 2266  2012          Ryan Baker       Louisiana State  OLB        71.38
# 2280  2012      Jamie Blatnick        Oklahoma State   DE        75.13
# 2285  2012       Nigel Bradham         Florida State  OLB        73.88
# 2286  2012        Andre Branch               Clemson   DE        76.25
# 2309  2012      Quinton Coples        North Carolina   DE        77.75
# 2315  2012     Tyrone Crawford           Boise State   DE        76.25
# 2324  2012       Lavonte David              Nebraska  OLB        72.63
# 2326  2012       Demario Davis        Arkansas State  OLB        74.00
# 2338  2012      Darius Fleming            Notre Dame  OLB        73.63
# 2344  2012      Justin Francis               Rutgers   DE        74.00
# 2391  2012       Melvin Ingram        South Carolina  OLB        73.50
# 2392  2012         Bruce Irvin         West Virginia  OLB        75.00
# ...

# %%
edges2013 = df[((df["POS"] == "DE") | (df["POS"] == "OLB"))&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 2012)&(df['Year'] < 2014)&(df['40\xa0Yard'] > 2)]
edges2013
# Out:
#       Year              Name                  College  POS  Height (in)  \
# 1967  2013     Ezekial Ansah            Brigham Young   DE        77.25
# 1982  2013        David Bass         Missouri Western   DE        75.88
# 2000  2013  Michael Buchanan                 Illinois   DE        77.38
# 2007  2013     Jamie Collins     Southern Mississippi  OLB        75.50
# 2040  2013  William Gholston           Michigan State   DE        78.25
# 2045  2013     Zaviar Gooden                 Missouri  OLB        73.50
# 2052  2013    Khaseem Greene                  Rutgers  OLB        72.75
# 2067  2013  DeVonte Holloman           South Carolina  OLB        73.38
# 2072  2013       Margus Hunt  Southern Methodist (TX)   DE        80.13
# 2094  2013      Datone Jones                     UCLA   DE        75.88
# 2104  2013        Joe Kruger                     Utah   DE        78.25
# 2109  2013    Corey Lemonier                   Auburn   DE        75.38
# ...

# %%
edges2014 = df[((df["POS"] == "DE") | (df["POS"] == "OLB"))&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 2013)&(df['Year'] < 2015)&(df['40\xa0Yard'] > 2)]
edges2014
# Out:
#       Year                Name                   College  POS  Height (in)  \
# 1667  2014        Anthony Barr                      UCLA  OLB        76.88
# 1684  2014       Carl Bradford             Arizona State  OLB        72.75
# 1692  2014      Jonathan Brown                  Illinois  OLB        72.38
# 1704  2014         Will Clarke             West Virginia   DE        78.13
# 1706  2014    Jadeveon Clowney            South Carolina   DE        77.25
# 1714  2014      Scott Crichton              Oregon State   DE        74.88
# 1727  2014           Kony Ealy                  Missouri   DE        76.00
# 1730  2014       Kasim Edebali            Boston College  OLB        74.00
# 1734  2014        IK Enemkpali            Louisiana Tech   DE        72.75
# 1758  2014         James Gayle             Virginia Tech   DE        75.75
# 1778  2014    Anthony Hitchens                      Iowa  OLB        72.38
# ...

# %%
edges2015 = df[((df["POS"] == "DE") | (df["POS"] == "OLB"))&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 2014)&(df['Year'] < 2016)&(df['40\xa0Yard'] > 2)]
edges2015
# Out:
#       Year                 Name             College  POS  Height (in)  \
# 921   2015       Kwon Alexander     Louisiana State  OLB        72.75
# 949   2015          Vic Beasley             Clemson  OLB        75.00
# 1013  2015    Anthony Chickillo          Miami (FL)   DE        75.13
# 1020  2015          Frank Clark            Michigan   DE        74.88
# 1057  2015          Aaron Davis      Colorado State  OLB        71.63
# 1076  2015      Xzavier Dickson             Alabama  OLB        75.50
# 1106  2015        Mario Edwards       Florida State   DE        74.63
# 1109  2015         Kyle Emanuel  North Dakota State  OLB        75.25
# 1132  2015         Trey Flowers            Arkansas   DE        74.13
# 1134  2015         Dante Fowler             Florida  OLB        74.63
# 1137  2015            Alani Fua       Brigham Young  OLB        76.75
# 1172  2015        Geneo Grissom            Oklahoma  OLB        75.38
# ...

# %%
edges2016 = df[((df["POS"] == "DE") | (df["POS"] == "OLB"))&(df['Shuttle'] > 2)&(df['3Cone'] > 2)&(df['Bench Press'] > 2)&(df['Year'] > 2015)&(df['Year'] < 2017)&(df['40\xa0Yard'] > 2)]
edges2016
# Out:
#      Year              Name                  College  POS  Height (in)  \
# 610  2016   Sterling Bailey                  Georgia   DE        76.00
# 617  2016      Ronald Blair   Appalachian State (NC)   DE        74.13
# 621  2016      Devante Bond                 Oklahoma  OLB        73.13
# 623  2016         Joey Bosa               Ohio State   DE        77.25
# 632  2016    Beniquez Brown        Mississippi State  OLB        72.75
# 636  2016  Jonathan Bullard                  Florida   DE        75.00
# 643  2016  Shilique Calhoun           Michigan State   DE        76.38
# 665  2016      James Cowser            Southern Utah   DE        75.13
# 688  2016     Jason Fanaika                     Utah   DE        73.75
# 732  2016   Branden Jackson               Texas Tech   DE        75.88
# 749  2016        Matt Judon  Grand Valley State (MI)   DE        75.00
# 752  2016   Bronson Kaufusi            Brigham Young   DE        78.50
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'
edges2012['Expected 3-cone']= 7.483 - (.0287 * edges2012["Height\xa0(in)"]) + (edges2012["Weight\xa0(lbs)"] * .0081)
edges2012
# Out:
#       Year                Name               College  POS  Height (in)  \
# 2266  2012          Ryan Baker       Louisiana State  OLB        71.38
# 2280  2012      Jamie Blatnick        Oklahoma State   DE        75.13
# 2285  2012       Nigel Bradham         Florida State  OLB        73.88
# 2286  2012        Andre Branch               Clemson   DE        76.25
# 2309  2012      Quinton Coples        North Carolina   DE        77.75
# 2315  2012     Tyrone Crawford           Boise State   DE        76.25
# 2324  2012       Lavonte David              Nebraska  OLB        72.63
# 2326  2012       Demario Davis        Arkansas State  OLB        74.00
# 2338  2012      Darius Fleming            Notre Dame  OLB        73.63
# 2344  2012      Justin Francis               Rutgers   DE        74.00
# 2391  2012       Melvin Ingram        South Carolina  OLB        73.50
# 2392  2012         Bruce Irvin         West Virginia  OLB        75.00
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'
edges2013['Expected 3-cone']= 7.483 - (.0287 * edges2013["Height\xa0(in)"]) + (edges2013["Weight\xa0(lbs)"] * .0081)
edges2013
# Out:
#       Year              Name                  College  POS  Height (in)  \
# 1967  2013     Ezekial Ansah            Brigham Young   DE        77.25
# 1982  2013        David Bass         Missouri Western   DE        75.88
# 2000  2013  Michael Buchanan                 Illinois   DE        77.38
# 2007  2013     Jamie Collins     Southern Mississippi  OLB        75.50
# 2040  2013  William Gholston           Michigan State   DE        78.25
# 2045  2013     Zaviar Gooden                 Missouri  OLB        73.50
# 2052  2013    Khaseem Greene                  Rutgers  OLB        72.75
# 2067  2013  DeVonte Holloman           South Carolina  OLB        73.38
# 2072  2013       Margus Hunt  Southern Methodist (TX)   DE        80.13
# 2094  2013      Datone Jones                     UCLA   DE        75.88
# 2104  2013        Joe Kruger                     Utah   DE        78.25
# 2109  2013    Corey Lemonier                   Auburn   DE        75.38
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'
edges2014['Expected 3-cone']= 7.483 - (.0287 * edges2014["Height\xa0(in)"]) + (edges2014["Weight\xa0(lbs)"] * .0081)
edges2014
# Out:
#       Year                Name                   College  POS  Height (in)  \
# 1667  2014        Anthony Barr                      UCLA  OLB        76.88
# 1684  2014       Carl Bradford             Arizona State  OLB        72.75
# 1692  2014      Jonathan Brown                  Illinois  OLB        72.38
# 1704  2014         Will Clarke             West Virginia   DE        78.13
# 1706  2014    Jadeveon Clowney            South Carolina   DE        77.25
# 1714  2014      Scott Crichton              Oregon State   DE        74.88
# 1727  2014           Kony Ealy                  Missouri   DE        76.00
# 1730  2014       Kasim Edebali            Boston College  OLB        74.00
# 1734  2014        IK Enemkpali            Louisiana Tech   DE        72.75
# 1758  2014         James Gayle             Virginia Tech   DE        75.75
# 1778  2014    Anthony Hitchens                      Iowa  OLB        72.38
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'
edges2015['Expected 3-cone']= 7.483 - (.0287 * edges2015["Height\xa0(in)"]) + (edges2015["Weight\xa0(lbs)"] * .0081)
edges2015
# Out:
#       Year                 Name             College  POS  Height (in)  \
# 921   2015       Kwon Alexander     Louisiana State  OLB        72.75
# 949   2015          Vic Beasley             Clemson  OLB        75.00
# 1013  2015    Anthony Chickillo          Miami (FL)   DE        75.13
# 1020  2015          Frank Clark            Michigan   DE        74.88
# 1057  2015          Aaron Davis      Colorado State  OLB        71.63
# 1076  2015      Xzavier Dickson             Alabama  OLB        75.50
# 1106  2015        Mario Edwards       Florida State   DE        74.63
# 1109  2015         Kyle Emanuel  North Dakota State  OLB        75.25
# 1132  2015         Trey Flowers            Arkansas   DE        74.13
# 1134  2015         Dante Fowler             Florida  OLB        74.63
# 1137  2015            Alani Fua       Brigham Young  OLB        76.75
# 1172  2015        Geneo Grissom            Oklahoma  OLB        75.38
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'
edges2016['Expected 3-cone']= 7.483 - (.0287 * edges2016["Height\xa0(in)"]) + (edges2016["Weight\xa0(lbs)"] * .0081)
edges2016
# Out:
#      Year              Name                  College  POS  Height (in)  \
# 610  2016   Sterling Bailey                  Georgia   DE        76.00
# 617  2016      Ronald Blair   Appalachian State (NC)   DE        74.13
# 621  2016      Devante Bond                 Oklahoma  OLB        73.13
# 623  2016         Joey Bosa               Ohio State   DE        77.25
# 632  2016    Beniquez Brown        Mississippi State  OLB        72.75
# 636  2016  Jonathan Bullard                  Florida   DE        75.00
# 643  2016  Shilique Calhoun           Michigan State   DE        76.38
# 665  2016      James Cowser            Southern Utah   DE        75.13
# 688  2016     Jason Fanaika                     Utah   DE        73.75
# 732  2016   Branden Jackson               Texas Tech   DE        75.88
# 749  2016        Matt Judon  Grand Valley State (MI)   DE        75.00
# 752  2016   Bronson Kaufusi            Brigham Young   DE        78.50
# ...
